# %% [markdown]
# # Análisis Matemático

# %% [markdown]
# # Macarena Pazos. Marzo 2021

# %% [markdown]
# # 2do Parcial (24/02/2021) - Derivadas, máximos, mínimos, derivadas parciales

# %% [markdown]
# # Criterios de evaluación.
#
# 1.- Proligidad.
#
# 2.- Pertinencia conceptual, síntesis y precisión.
#
# 3.- Desarrollo adecuado.
#
# 4.- Exactitud en los resultado.
#
# ### 5.- Para aquellos que no puedan realizar en Jupyter Notebook, seleccionen el medio a disposición, y apliquen los criterios mencionados antecedentemente.
#
# "Los incito a tratarnos, en la medida de lo posible, como lo que van a llegar a ser. Se que pueden, y estamos para ayudarlos a lograr ese objetivo".
#
# Keep learninig and practicing...

# %% [markdown]
# ## Link de notación matemática para Markdown
# https://www.overleaf.com/learn/latex/Integrals,_sums_and_limits
#
#
# ## Learn How to Write Markdown & LaTeX in The Jupyter Notebook
# https://towardsdatascience.com/write-markdown-latex-in-the-jupyter-notebook-10985edb91fd
#
# #### Markdown es el formato que nos permite escribir en el documento, en éste caso Jupyter Notebook.
# #### Utiliza un leguaje de texto llamado LaTeX.
# #### EL enlace conduce a un tutorial básico.
# #### Verán que es muy útil dado que nos permite escribir fórmulas y símbolos matemáticos.

# %% [markdown]
# ## Teorema de Bolzano
#
# https://es.wikipedia.org/wiki/Teorema_del_valor_intermedio

# %% [markdown]
# ### Ejercicio 1
#
# Dada la función $y=tan(x)$ y sabiendo que $f(\frac{\pi}{4})=1$ y $f(\frac{3}{4}\pi)=−1$ ,¿se puede asegurar por el teorema de Bolzano que existe $x=c$ perteneciente al intervalo $[\frac{\pi}{4},\frac{3}{4}\pi]$ tal que $f(c)=0$ ?
#
# No.
# Por el teorema de Bolzano sabemos que deben cumplirse las siguientes condiciones:
#
#  1- El signo de f(a) y el de f(b) deben ser distintos, lo cual es cierto.
#
#  2- Que la función sea continua en el intervalo cerrado: Sabemos que la función tangente es asintotica a valores cercanos a $\frac{\pi}{2}$. Además la tangente solo vale 0 cuando $x = 0$ o $x = \pi$ y ambos valores está fuera del intervalo.
#
# Por lo tanto no puedo aplicar el teorema de Bolzano.

# %% [markdown]
# # Derivadas

# %% [markdown]
# ### Ejercicio 2
#
# 5.- Resolver las derivadas:
#
# a) $ y= \frac{1}{(3x^4 + x - 8)^9} $
#
# -Aplico la ley de los exponentes:
#
# $ y= 1\cdot(3x^4 + x - 8)^{-9} $
#
# -Aplico la regla de la cadena:
#
# $ f'(x) = -9\cdot(3x^4 + x - 8)^{-10}\cdot {(12x^3 + 1)} $
#
# $ f'(x) = \frac{-9\cdot(12x^3 + 1)}{(3x^4 + x - 8)^{10}} $
#
#
# b) $ y = (3x^4 + x - 8)^{-3} $
#
# -Aplico la regla de la cadena:
# $ f'(x) = -3 \cdot (3x^4 + x - 8)^{-4} \cdot 12x^{3} $
#
# -Regla de los exponentes:
# $ f'(x) = \frac{-3 \cdot 12x^{3}}{(3x^4 + x - 8)^{4}}$
#
# c) $ f(x) = \frac {2x-3}{(x^2+4)^2}$
#
# -Aplico derivación por fracciones:
#
# $ f'(x) = \frac{2\dot (x^2+4)^{2} - (2x-3)\cdot2\cdot(x^2+4)\cdot2x}{(x^2+4)^{4}}$
#
# -Aplico factor común:
#
# $ f'(x) = 2(x^2+4)\frac{(x^2+4)- (2x-3)\cdot2x}{(x^2+4)^{4}}$
#
# -Simplifico:
#
# $ f'(x) =\frac{2 \cdot(x^2+4)- (2x-3)\cdot2x}{(x^2+4)^{3}}$
#
# $ f'(x) =\frac{2 \cdot(-3x^2+6x+4)}{(x^2+4)^{3}}$
#
#
# d) $ y = sen(3x^2 + 11x)$
#
# -Aplico la regla de la cadena:
#
# $ f'(x) = cos(3x^2 + 11x)\cdot(6x + 11)$

# %% [markdown]
# ### Ejercicio 3
#
# La función de ingresos de una empresa es: $$ I(q) = \frac{-6}{10^6}q^3 + \frac{18}{10^3}q^2 - 2q + 100 $$
#
#
# y la función  de  coste  total  es:  $$ C(q) = \frac{2}{10^2}q^2 - 24q + 11000 $$
# siendo  q  el  número  de  unidades  vendidas.
#
# Hallar el ingreso marginal y el coste marginal.
#
# Ingreso marginal:
#
# $ I(q) = \frac{-6}{10^6}q^3 + \frac{18}{10^3}q^2 - 2q + 100$
#
# -Aplico la regla de los exponentes:
#
# $ I(q) = \frac{-6 \cdot 3}{10^6}q^2 + \frac{18 \cdot 2}{10^3}q - 2$
#
# $ I(q) = \frac{-18}{10^6}q^2 + \frac{36}{10^3}q - 2$
#
# Coste marginal:
#
# $ C(q) = \frac{2}{10^2}q^2 - 24q + 11000 $
#
# -Aplico la regla de los exponentes:
#
# $ C(q) = \frac{4}{10^2}q - 24$

# %% [markdown]
# ### Ejercicio 4
#
# La regla de L'Hôpital nos ayuda a encontrar muchos límites donde la sustitución directa termina en las formas indeterminadas $\frac{0}{0}$, $\frac{0}{\infty}$ o $\frac{\infty}{\infty}$.
#
# Sean $f$ y $g$ dos funciones continuas definidas en el intervalo [a,b], derivables en (a,b) y sea c perteneciente a (a,b) tal que $f(c)=g(c)=0$ y $g'(x)≠0$ si $x≠c$.
#
# Si existe el límite $L$ de $\frac{f'}{g'}$ en c, entonces existe el límite de $\frac{f}{g} $ (en c) y es igual a $L$.
#
# Por lo tanto,
#
# $$ \lim _{x\to c} \frac{f(x)}{g(x)}=\lim _{x\to c}\frac{f'(x)}{g'(x)}=L  $$

# %% [markdown]
# Aplicar la regla de L'Hôpital para resolver la indeterminación de:
#
# a) $$ \lim_{x \to 1} \frac{ln(x)}{x-1} $$
#
# Sabemos que $ln(x)$ cuando tiende a 1 es 0, y que 1-1 = 0, entonces tenemos una indeterminación de tipo $\frac{0}{0}$
#
# -Aplico L'Hôpital:
#
# $ \lim_{x \to 1} \frac{\frac{1}{x}}{1} $
#
# -Luego por definición del límite el límite es 1.
#
#
# b) $$ \lim_{x \to 0} \frac{e^x - e^{-x}}{sen(x)} $$
#
# Vemos que $e^1 - e^{-1}$ cuando tiende a 0 es 0 y $sen(x)$ cuando tiende a 0 es 0, entonces tenemos una indeterminacion de tipo $\frac{0}{0}$
#
# -Aplico L'Hôpital:
#
# $ \lim_{x \to 0} \frac{e^x + e^{-x}}{cos(x)} $
#
# -Aplico definición del limite:
#
# $\frac{e^0 + e^{-0}}{cos(0)} \Rightarrow \frac{2}{1} = 2$
#
# c) $$ \hspace{1cm} lim_{x \to -2} \frac{x^2 + 7x + 10}{x +2} \hspace{1cm}  $$
#
# En este caso es fácil ver que el denominador se hace 0 cuando x tiende a -2, pero aplicando propiedades algebraicas se puede evitar.
#
# -Factorizo el numerador:
#
# $lim_{x \to -2} \frac{(x+2)(x+5)}{x +2}$
#
# -Simplifico y aplico definición de límite:
#
# $lim_{x \to -2} x+5 \Rightarrow -2 +5 = 3$

# %% [markdown]
# # Puntos de inflexión, máximos y mínimos

# %% [markdown]
# ### Ejercicio 5
#
# Se va a cortar una viga rectanguar de un tronco de seccion transversal circular. Si la resistencia de una viga es proporcional a su anchura y al cuadrado de su altura, encuentre las dimensiones de la seccion transversal que da a la viga la mayor resistencia.
#
# El enunciado nos pide maximizar la resistencia entonces:
#
# -Por el enunciado sabemos que:
#
# $R(a) = K \cdot a \cdot h^2$
#
# Donde K es la constante proporcional, a el ancho y h la altura
#
# -Sabemos también que se obtiene de un tronco de sección transversal circular, entonces deberíamos usar Pitagoras para determinar la longitud (l) a partir de su altura es decir:
#
# $l^2 = a^2 + h^2 \rightarrow l^2 - a^2 = h^2$
#
# -Entonces reemplazando:
#
# $R = K \cdot a \cdot (l^2 - a^2) \Rightarrow K \cdot a \cdot l^2 - K \cdot a^3 $
#
# -Los valores admisibles están entre $0< a < l $ Entonces, derivo en término de a:
#
# $R'(a) = K \cdot l^2 - K \cdot 3 \cdot a^2 $
#
# -Ahora busco el punto crítico para ver cual es la máxima resistencia:
#
# $K \cdot l^2 - K \cdot 3 \cdot a^2 = 0$
#
# $\Rightarrow l^2 - 3\cdot a^2 = 0$
#
# $\Rightarrow l^2 = 3\cdot a^2 $
#
# $\Rightarrow \frac{l^2}{3} = a^2 $
#
# $\Rightarrow \sqrt{\frac{l^2}{3}} = a $
#
# Como me da un único punto crítico es probable que sea el máximo de R:
#
# -Entonces para hallar las dimensiones tenemos que:
#
# $a = \frac{l}{\sqrt{3}}$
#
# $h^2 = l^2 - a^2 \Rightarrow h^2 = l^2 - (\frac{l}{\sqrt{3}})^2$
#
# $h^2 = l^2 - (\frac{l}{\sqrt{3}})^2 \Rightarrow h^2 = l^2 - (\frac{l^2}{3})$
#
# $h^2 = \frac{3 \cdot l^2 - l^2}{3} \Rightarrow h^2 = \frac{2 \cdot l^2}{3}$
#
# $h = \sqrt{\frac{2 \cdot l^2}{3}} \Rightarrow h = \sqrt{\frac{2}{3}} \cdot l $
#
# Entonces las dimensiones son:
#
# $h = \sqrt{\frac{2}{3}} \cdot l$
#
# $l = h \cdot \sqrt{\frac{3}{2}}$

# %% [markdown]
# ### Ejercicio 6
#
# Descomponer el número 25 en dos sumandos tales que el doble del cuadrado del primero más el triple del cuadrado del segundo sea mínimo.
#
# $f(x) = 2\cdot x^2 + 3 \cdot y^2$
#
# $25 = x + y \Rightarrow y = 25 - x$
#
# -Reemplazo y derivo:
#
# $f'(x) = 4x + 3 \cdot 2 (25 - x)(-1)$
#
# $f'(x) = 4x - 6 \cdot (25 - x)$
#
# $f'(x) = 4x - 6 \cdot 25 + 6x)$
#
# $f'(x) = 10x - 6 \cdot 25$
#
# -Prueba de la derivada para ver que es un mínimo:
#
# $f'(x) = 10x - 6 \cdot 25$
#
# $f''(x) = 10$, entonces es mínimo.
#
#
# -Igualo a 0 para encuntrar el valor de x:
#
# $10x - 6 \cdot 25 = 0$
#
# $10x  = 6 \cdot 25$
#
# $x  = 15$
#
# -Reemplazo:
#
# $25 = 15 + y \Rightarrow y = 10$
#
# -Entonces el valor mínimo es:
#
# $ 2\cdot 15^2 + 3 \cdot 10^2 = 750$

# %% [markdown]
# ### Ejercicio 7
#
# Un agricultor quiere alambrar una porción de campo de forma rectangular y que tenga 3600m2 de superficie. ¿Cómo le indicaríamos las dimensiones para que el coste sea mínimo?
#
# -Sabemos que el área de un rectangulo es base por altura:
#
# $3600 = b \cdot h$ (1)
#
# -Tambien sabemos que al ser un rectangulo dos de sus lados son iguales entre ellos:
#
# $f = b + b + h + h $
#
# $f = 2b + 2h $ (2)
#
# -Luego por 1 podemos reemlazar en 2:
#
# $f(h) = 2\cdot \frac{3600}{h} + 2h $
#
# $f(h) = \frac{7200}{h} + 2h $
#
# -Calculo la derivada:
#
# $f'(h) = -7200 \cdot h^2 + 2$
#
# -La igualo a 0 para encontrar el mínimo:
#
# $0 = \frac{-7200}{h^2} + 2$
#
# $\frac{7200}{h^2} = 2$
#
# $7200 = 2\cdot h^2$
#
# $\frac{7200}{2} = h^2$
#
# $\sqrt{3600} = h$
#
# $h = 60$
#
# Entonces la altura debe ser de $60m^2$
#
# -Reemplazo en 1:
#
# $3600 = b \cdot 60 $
#
# $\frac{3600}{60} = b $
#
# $ 60 = b $
#
# Podemos concluir que las dimensiones para el costo mínimo sería un cuadrado de 60 x 60 metros.

# %% [markdown]
# # Derivadas parciales

# %% [markdown]
# ## Funciones de dos o más Variables
#
# Existen magnitudes que dependen de dos o más variables independientes, por ejemplo,
#
# el  área  del  rectángulo depende  de  la  longitud  de  cada  uno  de  sus  lados,
#
# el  costo  de producción de una artículo depende del costo de los materiales y de la mano de obra,
#
# la  temperatura  que  tiene  un  gas  depende  del  volumen  que  ocupa  y  de  su  presión,
#
# la concentración   de   una   sustancia   en   cualquier punto   de   la   vena   luego   de   haber suministrado  una  inyección  depende  del  tiempo,  la  velocidad  de  la  sangre  y  la distancia en que se encuentra el punto de la inyección,
#
# Las funciones de dos variables se simbolizan $f: R^2 \to R $ y se representan generalmente $z = f(x; y)$

# %% [markdown]
# ## Definición.
# -Sea D un  conjunto  de  pares  ordenados, $ (x, y)$,  de  números  reales, $D \subset R^2$ .  Una  función  real  de  dos  variables  reales  es  una  regla que  asigna  a  cada  par ordenado (x, y) en D un único número real, denotado por $f (x, y)$.

# %% [markdown]
# La  derivada  de  una  función  de  una  variable  mide  la  rapidez  de  cambio  de  la variable  dependiente  respecto  a  la  variable  independiente.
#
# Para  funciones  de  dos variables x e y podemos medir dos razones de cambio: una según cambia y, dejando a x fija y otra según cambia x, dejando a y fija.

# %% [markdown]
# ### Ejercicio 8
#
# Evaluar las siguientes derivadas parciales de primer orden.
#
# 1- $ z= x^4 + 3y^3 + 2xy$
#
# -Aplico la regla de la suma:
#
# $\frac{\partial \:}{\partial \:x}\left(x^4+3y^3+2xy\right)=4x^3+2y$
#
# $\frac{\partial \:}{\partial \:y}\left(x^4+3y^3+2xy\right)=2x+9y^2$
#
# 2- $ z= (x^4 + 3y^3 + 2xy)^3 $
#
# -Aplico la regla de la cadena
#
# $\frac{\partial \:}{\partial \:x}\left(\left(x^4+3y^3+2xy\right)^3\right)=3\left(x^4+3y^3+2xy\right)^2\left(4x^3+2y\right)$
#
# $\frac{\partial \:}{\partial \:y}\left(\left(x^4+3y^3+2xy\right)^3\right)=3\left(x^4+3y^3+2xy\right)^2\left(9y^2+2x\right)$
#
#
# 3- $ z= e^{2x} + yln(x) $
#
# -Aplico la regla de la suma:
#
# $\frac{\partial \:}{\partial \:x}\left(e^{2x}\right)+\frac{\partial \:}{\partial \:x}\left(y\ln \left(x\right)\right)$
#
#
# $\frac{\partial \:}{\partial \:x}\left(e^{2x}+y\ln \left(x\right)\right)=e^{2x}\cdot \:2+\frac{y}{x}$
#
# -Aplico la regla de la suma:
#
# $\frac{\partial \:}{\partial \:y}\left(e^{2x}+y\ln \left(x\right)\right)=\ln \left(x\right)$

# %% [markdown]
# ### Ejercicio 9
#
# ### Funcion de demanda:
# Suponga que dos productos se venden a los precios p1 y p2, la cantidad demanda de cada uno de los productos depende de los precios de ambos productos en el mercado. Si q1 representa la demanda del primer producto entonces $ q1=f(p1,p2)$ es la función demanda de dicho producto y si q2 representa la demanda del segundo producto entonces $q2=g(p1,p2)$, por lo tanto las derivadas parciales de q1 y q2 se conocen como <b>funciones de demanda marginal </b>
#
# La función demanda par dos productos están dadas por:
#
# $$ q_1 = 300 - 8p_1 - 4p_2 $$
# $$ q_2 = 400 - 5p_1 - 10p_2 $$
#
#
# 1) Hallar la demanda para cada uno de ellos si el precio del primero es p1= 10 y del segundo p2=8.
#
# $q_1 = 300 - 8\cdot10 - 4\cdot8$
#
# $q_1 = 300 - 80 - 32$
#
# $q_1 = 188$
#
# $q_2 = 400 - 5\cdot10 - 10\cdot8$
#
# $q_2 = 400 - 50 - 80$
#
# $q_2 = 270$
#
# 2) Encuentre la demanda marginal de q1 respecto al precio p1
#
# $\frac{\partial \:q_1 }{\partial \:p_1}\left(\:300\:-\:8p_1\:-\:4p_2\:\right) = -8$
#
# 3) Encuentre la demanda marginal de q2 respecto al precio p2
#
# $\frac{\partial \:q_2 }{\partial \:p_2}\left(\:400\:-\:5p_1\:-\:10p_2\:\right) = -10$
#
# 4) Encuentre la demanda marginal de q1 respecto al precio p2
#
# $\frac{\partial \:q_1 }{\partial \:p_2}\left(\:300\:-\:8p_1\:-\:4p_2\:\right) = -4$
#
# 5) Encuentre la demanda marginal de q2 respecto al precio p1
#
# $\frac{\partial \:q_2 }{\partial \:p_1}\left(\:400\:-\:5p_1\:-\:10p_2\:\right) = -5$

# %% [markdown]
# ### Ejercicio 10
# Dada las siguiente expresión matemática, explique brevemente su aplicación en el contexto de los algoritmos de aprendizaje
#
# ![image.png](attachment:image.png)
#
# La expresión matematica es una función de coste para poder optimizar nuestros resultados.
# Mide la diferencia media al cuadrado entre los valores reales y predichos de una observación.
# El resultado es un único número que representa el coste, o puntuación, asociado a un conjunto actual de pesos. El objetivo es minimizar el mean square error para mejorar la precisión de un modelo.
